# %% [markdown]
# <a href="https://colab.research.google.com/github/rauan-assabayev/machine_learning_labs/blob/master/Lab_OpenCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Lab OpenCV**

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# **1) Read and Show**

# %%
img = cv2.imread('/content/gdrive/My Drive/OpenCVBlack.png',0)
plt.imshow(img, interpolation = 'bicubic')
#plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %% [markdown]
# **2) Resize**

# %%
dim = (100,100)
resized_img = cv2.resize(img,dim,interpolation=cv2.INTER_AREA)
plt.imshow(resized_img, interpolation = 'bicubic')
plt.show()

# %% [markdown]
# **3) Rotate**

# %%
(h, w) = resized_img.shape[:2]
center = (w / 2, h / 2)

angle180 = 180
 
scale = 1.0

M = cv2.getRotationMatrix2D(center, angle180, scale)
rotated_image = cv2.warpAffine(resized_img, M, (h, w))
plt.imshow(rotated_image, interpolation = 'bicubic')
plt.xticks([]), plt.yticks([])
plt.show()

# %% [markdown]
# **4) Transform**

# %%
y= 25
x= 25
h= 50
w= 50
cropped_image = rotated_image[y:y+h, x:x+w]
plt.xticks([]), plt.yticks([])
plt.imshow(cropped_image, interpolation = 'bicubic')
plt.show()

# %% [markdown]
# **5) Save**

# %%
cv.imwrite('/content/gdrive/My Drive/Logo.png',cropped_image)
# Out:
# True
